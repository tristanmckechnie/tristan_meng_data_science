# %% [markdown]
# # Playground for spectral denoising of returns data.

# %%
# import bespoke modules
from one_dimensional_time_series_forecasting import time_series_prediction, hit_rate, invert_first_difference,invert_first_difference_2,invert_scaling, invert_first_difference_with_log_2, invert_scaling,inverted_conclusion
from walkforward_validation import walk_forward_val, series_to_supervised
from spectral_denoising import automatic_fourier_denoising, automatic_fourier_denoising_wf, automatic_wavelet_denoising, automatic_wavelet_denoising_wf

# model evalution metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error

# data preprocessing
from sklearn.preprocessing import normalize
from sklearn.preprocessing import MinMaxScaler

# interactive figures
# %matplotlib widget 

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from tabulate import tabulate
# Out:
# 2022-05-25 21:49:04.830266: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-25 21:49:04.830313: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
financial_asset = 'CrudeOil'
column_to_predict = 'Close'
feat_engineering = 'difference_fourier'

# some forecasting parameters
window_length = 10
split = 500 # 44 for AirPlane


###################################################################################################
# import some data
###################################################################################################

df = pd.read_csv(f'./test_data/{financial_asset}_yfinance.csv') # sp_500 = GSPC.csv, # airplaine = AirPassengers.csv
df = df.iloc[-2000:,:].reset_index(drop=True) # only look at last 2000 days
# df['Date'] = df['Month']
df.plot(x='Date',y=f'{column_to_predict}',figsize=(10,5),legend=True,xlabel='Month',subplots=True)
plt.tight_layout()
display(df)

###################################################################################################
# feature engineer data
###################################################################################################

# step one: differencing

df['diff'] = df[f'{column_to_predict}'].diff(periods=1)
df['diff'].iloc[0] = 0

# step two: spectral denosing
signal = np.array(df['diff'][-2000:-split]) 
denoised_signal = automatic_fourier_denoising(signal,df, split,verbose=False)

df['diff_fourier'].iloc[-2000:-split] = denoised_signal 

###################################################################################################
# single out of sample validation results
###################################################################################################

# input data
scaler = MinMaxScaler()
scaled_training_data = scaler.fit_transform(df['diff'][0:-split].to_numpy().reshape(-1,1)).flatten()
scaled_test_data = scaler.transform(df['diff'][-split:].to_numpy().reshape(-1,1)).flatten()
scaled_input_data = np.append(scaled_training_data,scaled_test_data)

# initialize class object
blah = time_series_prediction(financial_asset,feat_engineering,df['Date'],scaled_input_data,window_length,1)#time_series_prediction(sp_500['Date'][-4000:],sp_500['Volume'][-4000:]/1e9,5,1) # pass: ime series dates, univariate time series, lag window length, a number of steps ahead to predict
blah.sliding_window_1(verbose=0) # time series to supervised ML problem
blah.train_test_split(split=split) # testing and training dataset split
blah.test_train_plot(ylabel='Differenced Close price')    # visualize training split

# perform some prediction tasks
blah.linear_regression()
blah.support_vector_machine(model_tunning=False,C= 0.1, kernel= 'linear',epsilon=0.1)
blah.neural_net_mlp(model_tunning=False,
                    activation= 'relu', 
                    hidden_layer_sizes= (100, 100, 100), 
                    learning_rate= 'invscaling', 
                    learning_rate_init= 0.001,
                    solver='adam')
# blah.lstm(model_tunning=True,n_batch=128)
blah.naive_model()

# tabulate results nicely
blah.collect_results()

# visualize results
blah.vis_results_time_series(ylabel='Differenced Close price',second_plot='error')

# view final results
blah.conclusion()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2014-01-22  95.199997  96.889999  95.120003  96.730003  96.730003
# 1     2014-01-23  96.690002  97.839996  96.410004  97.320000  97.320000
# 2     2014-01-24  97.370003  97.800003  96.250000  96.639999  96.639999
# 3     2014-01-27  96.900002  97.180000  95.209999  95.720001  95.720001
# 4     2014-01-28  95.660004  97.660004  95.629997  97.410004  97.410004
# ...          ...        ...        ...        ...        ...        ...
# 1995  2021-12-23  73.029999  73.949997  72.269997  73.790001  73.790001
# 1996  2021-12-27  73.379997  76.089996  72.570000  75.570000  75.570000
# 1997  2021-12-28  75.970001  76.919998  75.529999  75.980003  75.980003
# 1998  2021-12-29  76.040001  77.370003  75.360001  76.559998  76.559998
# 1999  2021-12-30  76.580002  77.440002  75.779999  76.989998  76.989998
#
#       Volume
# 0     252349
# 1     274078
# 2     239673
# 3     235110
# 4     206490
# ...      ...
# 1995  270223
# 1996  268490
# 1997  249728
# 1998  283557
# 1999  231163
#
# [2000 rows x 7 columns]
# /tmp/ipykernel_480625/1276424153.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['diff'].iloc[0] = 0
# /home/tristan/my_venvs/meng-data-science/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:681: RuntimeWarning: invalid value encountered in true_divide
#   acf = avf[: nlags + 1] / avf[0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Untitled-1.ipynb Cell 3' in <cell line: 32>()
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=29'>30</a> # step two: spectral denosing
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=30'>31</a> signal = np.array(df['diff'][-2000:-split])
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=31'>32</a> denoised_signal = automatic_fourier_denoising(signal,df, split,verbose=False)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=33'>34</a> df['diff_fourier'].iloc[-2000:-split] = denoised_signal
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=35'>36</a> ###################################################################################################
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=36'>37</a> # single out of sample validation results
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=37'>38</a> ###################################################################################################
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=38'>39</a>
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=39'>40</a> # input data
#
# File ~/Repos/tristan_meng_data_science/spectral_denoising.py:112, in automatic_fourier_denoising(signal, df, split, verbose)
#     <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=102'>103</a> """
#     <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=103'>104</a> This function implement automatic fourier denoising on a time series signal.
#     <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=104'>105</a>
#    (...)
#     <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=107'>108</a> params: split: where the training - testing split happens. From the end. |------split<----|
#     <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=108'>109</a> """
#     <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=110'>111</a> # step 1: Apply FFT and find threshold
# --> <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=111'>112</a> white_noise_threshold = find_threshold(signal,verbose=verbose)
#     <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=113'>114</a> # step 2: Apply FFT and produce PSD
#     <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=114'>115</a> fft_coefficients = fft(signal)
#
# File ~/Repos/tristan_meng_data_science/spectral_denoising.py:87, in find_threshold(signal, verbose)
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=83'>84</a>     inverse_transform_noise = ifft(fft_filtered_noise)
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=85'>86</a>     # is this removed component white noise?
# ---> <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=86'>87</a>     white_noise_1_0, percentage = test_for_white_noise(inverse_transform_noise)
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=88'>89</a>     # if white_noise_1_0 == True:
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=89'>90</a>         # print(f'Threshold found! Threshold: {threshold} Test: {percentage}')
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=91'>92</a> if verbose != False:
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=92'>93</a>     # some white noise evidence
#
# File ~/Repos/tristan_meng_data_science/spectral_denoising.py:23, in test_for_white_noise(inverse_transform_noise)
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=14'>15</a> """
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=15'>16</a> This function is used to test whether the noise component removed from the signal is
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=16'>17</a> white noise or not. If it is white noise it returns True, otherwise False.
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=17'>18</a>
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=18'>19</a> The test used to determine white noise or not is from: https://otexts.com/fpp2/wn.html
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=19'>20</a> """
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=21'>22</a> # compute autocorrelations
# ---> <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=22'>23</a> acf_values = acf(np.real(inverse_transform_noise),nlags=100)
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=24'>25</a> # compute boundary for acceptable for white noise
#      <a href='file:///~/Repos/tristan_meng_data_science/spectral_denoising.py?line=25'>26</a> critical_val = 2/np.sqrt(len(inverse_transform_noise))
#
# File ~/my_venvs/meng-data-science/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:680, in acf(x, adjusted, nlags, qstat, fft, alpha, bartlett_confint, missing)
#     <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/statsmodels/tsa/stattools.py?line=676'>677</a> if nlags is None:
#     <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/statsmodels/tsa/stattools.py?line=677'>678</a>     nlags = min(int(10 * np.log10(nobs)), nobs - 1)
# --> <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/statsmodels/tsa/stattools.py?line=679'>680</a> avf = acovf(x, adjusted=adjusted, demean=True, fft=fft, missing=missing)
#     <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/statsmodels/tsa/stattools.py?line=680'>681</a> acf = avf[: nlags + 1] / avf[0]
#     <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/statsmodels/tsa/stattools.py?line=681'>682</a> if not (qstat or alpha):
#
# File ~/my_venvs/meng-data-science/lib/python3.8/site-packages/pandas/util/_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/pandas/util/_decorators.py?line=204'>205</a>     else:
#     <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/pandas/util/_decorators.py?line=205'>206</a>         kwargs[new_arg_name] = new_arg_value
# --> <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/pandas/util/_decorators.py?line=206'>207</a> return func(*args, **kwargs)
#
# File ~/my_venvs/meng-data-science/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:517, in acovf(x, adjusted, demean, fft, missing, nlag)
#     <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/statsmodels/tsa/stattools.py?line=514'>515</a> nobs = len(xo)
#     <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/statsmodels/tsa/stattools.py?line=515'>516</a> n = _next_regular(2 * nobs + 1)
# --> <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/statsmodels/tsa/stattools.py?line=516'>517</a> Frf = np.fft.fft(xo, n=n)
#     <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/statsmodels/tsa/stattools.py?line=517'>518</a> acov = np.fft.ifft(Frf * np.conjugate(Frf))[:nobs] / d[nobs - 1 :]
#     <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/statsmodels/tsa/stattools.py?line=518'>519</a> acov = acov.real
#
# File <__array_function__ internals>:180, in fft(*args, **kwargs)
#
# File ~/my_venvs/meng-data-science/lib/python3.8/site-packages/numpy/fft/_pocketfft.py:215, in fft(a, n, axis, norm)
#     <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/numpy/fft/_pocketfft.py?line=212'>213</a>     n = a.shape[axis]
#     <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/numpy/fft/_pocketfft.py?line=213'>214</a> inv_norm = _get_forward_norm(n, norm)
# --> <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/numpy/fft/_pocketfft.py?line=214'>215</a> output = _raw_fft(a, n, axis, False, True, inv_norm)
#     <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/numpy/fft/_pocketfft.py?line=215'>216</a> return output
#
# File ~/my_venvs/meng-data-science/lib/python3.8/site-packages/numpy/fft/_pocketfft.py:70, in _raw_fft(a, n, axis, is_real, is_forward, inv_norm)
#      <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/numpy/fft/_pocketfft.py?line=66'>67</a>         a = z
#      <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/numpy/fft/_pocketfft.py?line=68'>69</a> if axis == a.ndim-1:
# ---> <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/numpy/fft/_pocketfft.py?line=69'>70</a>     r = pfi.execute(a, is_real, is_forward, fct)
#      <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/numpy/fft/_pocketfft.py?line=70'>71</a> else:
#      <a href='file:///~/my_venvs/meng-data-science/lib/python3.8/site-packages/numpy/fft/_pocketfft.py?line=71'>72</a>     a = swapaxes(a, axis, -1)
#
# KeyboardInterrupt:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
